# %%
import requests
import pandas as pd 
key = 'AIzaSyCdZbZ-Q1ROLoqMU6gMvirPqIu4Sm5FNQc'
address = input("What stadium are you visiting? ")

params = { 'address' : address, 'key' : key}
url = 'https://maps.googleapis.com/maps/api/geocode/json' # geocoding

try: 
    

    response = requests.get(url, params = params)
    location = response.json()
    coords = location['results'][0]['geometry']['location']
    lat = (coords['lat'])
    lng = (coords['lng'])
    coordinates = (lat,lng)

except IndexError:
    print("Please enter a valid stadium. ")
    
key= 'AIzaSyCdZbZ-Q1ROLoqMU6gMvirPqIu4Sm5FNQc'
search=input("What do you want to find?: ")
url= 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=%s,%s&radius=2500&keyword=%s&key=AIzaSyCdZbZ-Q1ROLoqMU6gMvirPqIu4Sm5FNQc'% (lat,lng, search)

response = requests.get(url, params = params)
output = response.json()
places=output['results']

x = pd.DataFrame(places, columns = ['name','price_level','rating','vicinity'])
print("Welcome to %s! Here are some suggestions of %ss for you to try while you're in the city! " % (address,search))
x.sort_values(by= 'rating', ascending = False)
# Out:
# What stadium are you visiting? Wrigley Field
# What do you want to find?: bar
# Welcome to Wrigley Field! Here are some suggestions of bars for you to try while you're in the city!
#                                name  price_level  rating  \
# 7                      The Northman          2.0     4.7
# 14                   Schubas Tavern          2.0     4.6
# 4             Will's Northwoods Inn          1.0     4.6
# 0                  The Bar on Buena          2.0     4.5
# 13                   The Green Mill          3.0     4.5
# 10               Murphy's Bleachers          2.0     4.5
# 5                      Fountainhead          2.0     4.4
# 12                      Frank's Bar          1.0     4.4
# 16                   The Green Lady          NaN     4.4
# 9                      Bar Pastoral          2.0     4.3
# 3                   Village Tap Bar          1.0     4.3
# 2               Replay Lincoln Park          2.0     4.3
# 15             Merkle's Bar & Grill          NaN     4.2
# 8                          Smartbar          2.0     4.1
# 11                      Scarlet Bar          1.0     4.1
# 17             Progress Bar Chicago          1.0     4.1
# 18  Sluggers World Class Sports Bar          2.0     4.1
# 6                         Driftwood          1.0     4.0
# 19   Ravenswood Station Bar & Grill          1.0     3.9
# 1               Chicago Bar Project          NaN     0.0
#
#                                        vicinity
# 7                   4337 N Lincoln Ave, Chicago
# 14                3159 N Southport Ave, Chicago
# 4                    3030 N Racine Ave, Chicago
# 0                      910 W Buena Ave, Chicago
# 13                     4802 N Broadway, Chicago
# 10                3655 N Sheffield Ave, Chicago
# 5                  1970 W Montrose Ave, Chicago
# 12                     2503 N Clark St, Chicago
# 16                  3328 N Lincoln Ave, Chicago
# 9                      2947 N Broadway, Chicago
# 3                     2055 W Roscoe St, Chicago
# 2                 2833 N Sheffield Ave, Chicago
# 15                     3516 N Clark St, Chicago
# 8   Metro / Smart Bar, 3730 N Clark St, Chicago
# 11                   3320 N Halsted St, Chicago
# 17                   3359 N Halsted St, Chicago
# 18                     3540 N Clark St, Chicago
# 6                  1021 W Montrose Ave, Chicago
# 19                    4709 N Damen Ave, Chicago
# 1         3047 N Lincoln Ave Suite 435, Chicago
